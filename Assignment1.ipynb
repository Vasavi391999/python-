# %% [markdown]
# 1.In the below elements which of them are values or an expression? eg:- values can be integer or string and expression will be mathematical operators.
# *, 'hello', -87.8, -, /, +, 6
#
# Ans: There are total of 4 operators and 3 expressions, they are
# operators: *, -, /, +
# expressions: 'hello', -87.8, 6

# %% [markdown]
# 2. What is the difference between string and variable?
#
# Ans: A variable is used to store information and a string is a type of information that you would store in a variable. A string is a group of character or a single character usually enclosed in double quotes or single quotes

# %% [markdown]
# 3. Describe three different Data Types?
#
# Ans: int data type: To represent whole numbers we use int data type
#      float data type: To represent decimal values we use float data type
#      string data type: To represet characters we use string data type

# %%
int_num = 4567
type(int_num)
# Out:
# int

# %%
float = 3.522
type(float)
# Out:
# float

# %%
company_name = 'freshmart'
type(company_name)
# Out:
# str

# %% [markdown]
# 4. what is an expression made up of ? what do all expressions do?
#
# Ans: An expression is a combination of values, variables, opeartors, and calls to functions. Expression need to be evaluated

# %%
4+5-20/2
# Out:
# -1.0

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
# Ans:  An expression is a combination of values, variables, opeartors, and calls to functions. Expression need to be evaluated
# A statement is a unit of code that has an effect like creating a variable or displaying a value.

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
# case 1
bacon = 22
bacon + 1
print(bacon)
# Out:
# 22

# %%
# case 2
bacon = 22
bacon = bacon + 1
print(bacon)
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam'+'spamspam'
#
# 'spam'*3
#
# Ans: Both expression evaluate to the string 'spamspam' where as the first expression follows string concatination and the second expression follows string multiplication

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans: As per python, variable names cannot begin with number

# %%
egg = 'hello'
print(egg)
# Out:
# hello

# %%
100 = 'ineuron'
print(100)
# Out:
#   File "<ipython-input-15-c73ad48d3545>", line 1
#     100 = 'ineuron'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# 9.What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# Ans: int(), float(), str() functions can be used to get integer, float,string

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 + 'burritos.'
#
# Ans: This cause of error is 99. because 99 is not a string. 99 must be typecasted to a string to fix this error the correct way is 'I have eaten' + str(99) + 'burritos.'

# %%
print('I have eaten' + str(99) + 'burritos')
# Out:
# I have eaten99burritos
